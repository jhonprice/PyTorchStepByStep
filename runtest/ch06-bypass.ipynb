# %% [markdown]
# # CH04的细节问题
#
# - `download_rps`
# - `figure1`
# - `n_samples = torch.tensor([n_samples]*n_channels).float()`
# - `means.sum(axis=0)`
# - `torch.stack([n_samples, sum_means, sum_stds], axis=0)`
# - `StepByStep.loader_apply(loader, StepByStep.statistics_per_channel)`
# - `figure2(first_images, first_labels)`
# - `torch.linspace(.1, 1.1, 11)`
# - ` [F.linear(F.dropout(spaced_points, p=p)
#               ,weight=torch.ones(11), bias=torch.tensor(0))
#                 for _ in range(1000)
#     ]` 列表推导式
# - `figure7` `figure8` `figure9`
# - `super(CNN2, self).__init__()`python的类继承
# - `F.linear`
# - `StepByStep.plot_losses`
# - `StepByStep.correct`
# - `ax.set_xscale`
# - `plt.subplots`
# - `ax.get_figure()`
# - `figure15`
